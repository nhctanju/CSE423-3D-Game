# %%
from OpenGL.GL import *
from OpenGL.GLUT import *
from OpenGL.GLU import *
from OpenGL.GLUT import GLUT_BITMAP_HELVETICA_18

import sys
import math

# Camera control
camera_angle = [0, 0]
camera_pos = [0, 5, 20]

# Flag positions
red_flag_pos = [-10, 0, -10]
blue_flag_pos = [10, 0, 10]
# player positions
player_pos = [0.0, 0.0, 0.0]
player_speed = 0.5
key_states = {b"w": False, b"s": False, b"a": False, b"d": False}
player_health = 5
# Direction player is facing: [dx, dy, dz]
player_direction = [0, 0, 1]  # Initially facing +Z (forward)


player_has_flag = False

player_wins = False

fireballs = []  # List of fireballs, each is a dict with position and velocity
fireball_speed = 1.0

tower_pos = [10.0, 0.0, 7.0]  # Near the blue flag
tower_fireballs = []
tower_fireball_speed = 0.5
tower_cooldown = 0  # Countdown until next fire
tower_alerted = False


def init():
    glClearColor(0.5, 0.8, 1.0, 1.0)  # Sky blue background
    glEnable(GL_DEPTH_TEST)
    glShadeModel(GL_SMOOTH)
    glutKeyboardFunc(key_down)
    glutKeyboardUpFunc(key_up)
    glutMouseFunc(mouse_click)

def draw_text(x, y, text, font=GLUT_BITMAP_HELVETICA_18):
    glColor3f(1, 1, 1)
    glMatrixMode(GL_PROJECTION)
    glPushMatrix()
    glLoadIdentity()
    gluOrtho2D(0, 800, 0, 600)
    glMatrixMode(GL_MODELVIEW)
    glPushMatrix()
    glLoadIdentity()
    glRasterPos2f(x, y)
    for ch in text:
        glutBitmapCharacter(font, ord(ch))
    glPopMatrix()
    glMatrixMode(GL_PROJECTION)
    glPopMatrix()
    glMatrixMode(GL_MODELVIEW)


def reshape(w, h):
    glViewport(0, 0, w, h)
    glMatrixMode(GL_PROJECTION)
    glLoadIdentity()
    gluPerspective(60.0, float(w)/float(h), 1.0, 100.0)
    glMatrixMode(GL_MODELVIEW)

def draw_flag(position, color):
    glPushMatrix()
    glTranslatef(*position)
    glColor3fv(color)
    glutSolidCube(1.0)
    glPopMatrix()

def draw_base(position, color):
    glPushMatrix()
    glTranslatef(*position)
    glScalef(4, 0.2, 4)
    glColor3fv(color)
    glutSolidCube(1.0)
    glPopMatrix()

# Assume this is your shared ground render function
def render_ground():
    glColor3f(0.3, 0.6, 0.3)  # Grass green
    glBegin(GL_QUADS)
    glVertex3f(-50, -0.1, -50)
    glVertex3f(-50, -0.1, 50)
    glVertex3f(50, -0.1, 50)
    glVertex3f(50, -0.1, -50)
    glEnd()









def display():
    glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
    glLoadIdentity()
    update_player()
    check_flag_pickup()
    update_fireballs()
    

    # Set camera
    gluLookAt(camera_pos[0], camera_pos[1], camera_pos[2],
              0, 0, 0,
              0, 1, 0)

    # Draw terrain
    render_ground()

    # Draw bases
    draw_base([-10, 0, -10], (1, 0, 0))  # Red base
    draw_base([10, 0, 10], (0, 0, 1))    # Blue base

    # Draw flags
    if not player_has_flag:
        draw_flag(blue_flag_pos, (0, 0, 1))
    draw_flag(red_flag_pos, (1, 0, 0))

    # Draw player
    glPushMatrix()
    glTranslatef(*player_pos)
    glColor3f(1, 1, 0)  # Yellow
    glutSolidCube(1.0)
    glPopMatrix()

    if player_wins:
        draw_text(300, 300, "🏁 YOU WIN!",GLUT_BITMAP_HELVETICA_18)

    # Draw fireballs
    for fb in fireballs:
        glPushMatrix()
        glTranslatef(*fb["pos"])
        glColor3f(1, 0.5, 0)  # Orange
        glutSolidSphere(0.3, 10, 10)
        glPopMatrix()

    # Draw the tower
    glPushMatrix()
    glTranslatef(*tower_pos)
    glColor3f(0.3, 0.3, 0.3)  # Gray
    glScalef(1, 3, 1)
    glutSolidCube(1.0)
    glPopMatrix()

    # Draw tower fireballs
    for fb in tower_fireballs:
        glPushMatrix()
        glTranslatef(*fb["pos"])
        glColor3f(1.0, 0.1, 0.1)  # Red fireball
        glutSolidSphere(0.3, 10, 10)
        glPopMatrix()
        # Show player health in top-left corner
    draw_text(10, 570, f"Health: {player_health}", font=GLUT_BITMAP_HELVETICA_18, color=(1, 0, 0))
    
    glutSwapBuffers()

def key_down(key, x, y):
    if key in key_states:
        key_states[key] = True
    elif key == b' ':  # Spacebar
        shoot_fireball()

def key_up(key, x, y):
    if key in key_states:
        key_states[key] = False

def mouse_click(button, state, x, y):
    if button == GLUT_LEFT_BUTTON and state == GLUT_DOWN:
       
        reset_game()


def update_player():
    global player_direction

    if key_states[b"w"]:
        player_pos[2] -= player_speed
        player_direction = [0, 0, -1]
    if key_states[b"s"]:
        player_pos[2] += player_speed
        player_direction = [0, 0, 1]
    if key_states[b"a"]:
        player_pos[0] -= player_speed
        player_direction = [-1, 0, 0]
    if key_states[b"d"]:
        player_pos[0] += player_speed
        player_direction = [1, 0, 0]

def distance(p1, p2):
    return math.sqrt(sum([(p1[i] - p2[i])**2 for i in range(3)]))




def shoot_fireball():
    fireball = {
        "pos": player_pos[:],       # copy current position
        "vel": player_direction[:]  # copy current facing direction
    }
    fireballs.append(fireball)


def update_fireballs():
    global fireballs, tower_alerted

    new_fireballs = []
    for fb in fireballs:
        # Update position
        fb["pos"] = [fb["pos"][i] + fb["vel"][i] * fireball_speed for i in range(3)]

        # Check for tower collision
        if distance(fb["pos"], tower_pos) < 1.5:
            tower_alerted = True
            print("🚨 Tower alerted by player's fireball!")
            continue  # Remove this fireball after hitting

        # Keep fireball in scene bounds
        if -50 < fb["pos"][0] < 50 and -50 < fb["pos"][2] < 50:
            new_fireballs.append(fb)

    fireballs = new_fireballs






def shoot_tower_fireball():
    dir_vec = [player_pos[i] - tower_pos[i] for i in range(3)]
    magnitude = math.sqrt(sum([x**2 for x in dir_vec]))
    if magnitude == 0:
        return
    velocity = [x / magnitude for x in dir_vec]
    fireball = {
        "pos": tower_pos[:],
        "vel": velocity
    }
    tower_fireballs.append(fireball)





def main():
    glutInit(sys.argv)
    glutInitDisplayMode(GLUT_DOUBLE | GLUT_RGB | GLUT_DEPTH)
    glutInitWindowSize(800, 600)
    glutCreateWindow(b"Capture the Flag 3D Environment")
    init()
    glutDisplayFunc(display)
    glutReshapeFunc(reshape)
    glutIdleFunc(glutPostRedisplay)
    glutMainLoop()

if __name__ == '__main__':
    main()
# Out:
# 🚩 Blue Flag Captured!
# Checking hit: Fireball at [9.878732187481834, 0.0, 7.485071250072666], Player at [9.0, 0.0, 11.0], Distance = 3.62
# Checking hit: Fireball at [9.757464374963668, 0.0, 7.970142500145332], Player at [9.5, 0.0, 11.0], Distance = 3.04
# Checking hit: Fireball at [9.636196562445502, 0.0, 8.455213750217998], Player at [10.0, 0.0, 11.0], Distance = 2.57
# Checking hit: Fireball at [9.514928749927336, 0.0, 8.940285000290665], Player at [10.5, 0.0, 11.0], Distance = 2.28
# Checking hit: Fireball at [9.39366093740917, 0.0, 9.42535625036333], Player at [11.0, 0.0, 11.0], Distance = 2.25
# Checking hit: Fireball at [9.272393124891003, 0.0, 9.910427500435997], Player at [11.5, 0.0, 11.0], Distance = 2.48
# Checking hit: Fireball at [9.151125312372837, 0.0, 10.395498750508663], Player at [12.0, 0.0, 11.0], Distance = 2.91
# Checking hit: Fireball at [9.029857499854671, 0.0, 10.88057000058133], Player at [12.0, 0.0, 11.0], Distance = 2.97
# Checking hit: Fireball at [8.908589687336505, 0.0, 11.365641250653995], Player at [12.0, 0.0, 11.0], Distance = 3.11
# Checking hit: Fireball at [8.787321874818339, 0.0, 11.850712500726662], Player at [12.0, 0.0, 11.0], Distance = 3.32
# Checking hit: Fireball at [8.666054062300173, 0.0, 12.335783750799328], Player at [12.0, 0.0, 11.0], Distance = 3.59
# Checking hit: Fireball at [8.544786249782007, 0.0, 12.820855000871994], Player at [12.0, 0.0, 11.0], Distance = 3.91
# Checking hit: Fireball at [8.42351843726384, 0.0, 13.30592625094466], Player at [12.0, 0.0, 11.0], Distance = 4.26
# Checking hit: Fireball at [8.302250624745675, 0.0, 13.790997501017326], Player at [12.0, 0.0, 11.0], Distance = 4.63
# Checking hit: Fireball at [8.180982812227509, 0.0, 14.276068751089992], Player at [12.0, 0.0, 11.0], Distance = 5.03
# Checking hit: Fireball at [8.059714999709342, 0.0, 14.761140001162659], Player at [12.0, 0.0, 11.0], Distance = 5.45
# Checking hit: Fireball at [7.938447187191176, 0.0, 15.246211251235325], Player at [12.0, 0.0, 11.0], Distance = 5.88
# Checking hit: Fireball at [7.81717937467301, 0.0, 15.73128250130799], Player at [12.0, 0.0, 11.0], Distance = 6.32
# Checking hit: Fireball at [7.695911562154844, 0.0, 16.216353751380655], Player at [12.0, 0.0, 11.0], Distance = 6.76
# Checking hit: Fireball at [7.574643749636678, 0.0, 16.70142500145332], Player at [12.0, 0.0, 11.0], Distance = 7.22
# Checking hit: Fireball at [7.453375937118512, 0.0, 17.186496251525984], Player at [11.5, 0.0, 11.0], Distance = 7.39
# Checking hit: Fireball at [7.332108124600346, 0.0, 17.67156750159865], Player at [11.0, 0.0, 11.0], Distance = 7.61
# Checking hit: Fireball at [7.21084031208218, 0.0, 18.156638751671313], Player at [10.5, 0.0, 11.0], Distance = 7.88
# Checking hit: Fireball at [7.089572499564014, 0.0, 18.641710001743977], Player at [10.0, 0.0, 11.0], Distance = 8.18
# Checking hit: Fireball at [6.968304687045848, 0.0, 19.12678125181664], Player at [9.5, 0.0, 11.0], Distance = 8.51
# Checking hit: Fireball at [6.8470368745276815, 0.0, 19.611852501889306], Player at [9.0, 0.0, 11.0], Distance = 8.88
# Checking hit: Fireball at [6.725769062009515, 0.0, 20.09692375196197], Player at [8.5, 0.0, 11.0], Distance = 9.27
# Checking hit: Fireball at [6.604501249491349, 0.0, 20.581995002034635], Player at [8.0, 0.0, 11.0], Distance = 9.68
# Checking hit: Fireball at [6.483233436973183, 0.0, 21.0670662521073], Player at [7.5, 0.0, 11.0], Distance = 10.12
# Checking hit: Fireball at [6.361965624455017, 0.0, 21.552137502179963], Player at [7.0, 0.0, 11.0], Distance = 10.57
# Checking hit: Fireball at [6.240697811936851, 0.0, 22.037208752252628], Player at [6.5, 0.0, 11.0], Distance = 11.04
# Checking hit: Fireball at [6.119429999418685, 0.0, 22.522280002325292], Player at [6.0, 0.0, 11.0], Distance = 11.52
# Checking hit: Fireball at [5.998162186900519, 0.0, 23.007351252397957], Player at [5.5, 0.0, 11.0], Distance = 12.02
# Checking hit: Fireball at [5.876894374382353, 0.0, 23.49242250247062], Player at [5.0, 0.0, 11.0], Distance = 12.52
# Checking hit: Fireball at [5.755626561864187, 0.0, 23.977493752543285], Player at [4.5, 0.0, 11.0], Distance = 13.04
# Checking hit: Fireball at [5.6343587493460205, 0.0, 24.46256500261595], Player at [4.0, 0.0, 11.0], Distance = 13.56
# Checking hit: Fireball at [5.5130909368278544, 0.0, 24.947636252688614], Player at [3.5, 0.0, 11.0], Distance = 14.09
# Checking hit: Fireball at [5.391823124309688, 0.0, 25.43270750276128], Player at [3.0, 0.0, 11.0], Distance = 14.63
# Checking hit: Fireball at [5.270555311791522, 0.0, 25.917778752833943], Player at [2.5, 0.0, 11.0], Distance = 15.17
# Checking hit: Fireball at [5.149287499273356, 0.0, 26.402850002906607], Player at [2.0, 0.0, 11.0], Distance = 15.72
# Checking hit: Fireball at [5.02801968675519, 0.0, 26.88792125297927], Player at [1.5, 0.0, 11.0], Distance = 16.27
# Checking hit: Fireball at [4.906751874237024, 0.0, 27.372992503051936], Player at [1.0, 0.0, 11.0], Distance = 16.83
# Checking hit: Fireball at [4.785484061718858, 0.0, 27.8580637531246], Player at [0.5, 0.0, 11.0], Distance = 17.39
# Checking hit: Fireball at [4.664216249200692, 0.0, 28.343135003197265], Player at [0.0, 0.0, 11.0], Distance = 17.96
# Checking hit: Fireball at [4.542948436682526, 0.0, 28.82820625326993], Player at [-0.5, 0.0, 11.0], Distance = 18.53
# Checking hit: Fireball at [4.42168062416436, 0.0, 29.313277503342594], Player at [-1.0, 0.0, 11.0], Distance = 19.10
# Checking hit: Fireball at [4.3004128116461935, 0.0, 29.798348753415258], Player at [-1.5, 0.0, 11.0], Distance = 19.67
# Checking hit: Fireball at [4.179144999128027, 0.0, 30.283420003487922], Player at [-2.0, 0.0, 11.0], Distance = 20.25
# Checking hit: Fireball at [4.057877186609861, 0.0, 30.768491253560587], Player at [-2.5, 0.0, 11.0], Distance = 20.83
# Checking hit: Fireball at [3.9366093740916948, 0.0, 31.25356250363325], Player at [-3.0, 0.0, 11.0], Distance = 21.41
# Checking hit: Fireball at [3.815341561573528, 0.0, 31.738633753705916], Player at [-3.5, 0.0, 11.0], Distance = 21.99
# Checking hit: Fireball at [3.6940737490553617, 0.0, 32.22370500377858], Player at [-4.0, 0.0, 11.0], Distance = 22.58
# Checking hit: Fireball at [3.572805936537195, 0.0, 32.70877625385125], Player at [-4.0, 0.0, 11.0], Distance = 22.99
# Checking hit: Fireball at [3.4515381240190286, 0.0, 33.19384750392391], Player at [-4.0, 0.0, 11.0], Distance = 23.41
# Checking hit: Fireball at [3.330270311500862, 0.0, 33.67891875399658], Player at [-4.0, 0.0, 11.0], Distance = 23.83
# Checking hit: Fireball at [3.2090024989826955, 0.0, 34.16399000406924], Player at [-4.0, 0.0, 11.0], Distance = 24.26
# Checking hit: Fireball at [3.087734686464529, 0.0, 34.649061254141905], Player at [-4.0, 0.0, 11.0], Distance = 24.69
# Checking hit: Fireball at [2.9664668739463624, 0.0, 35.13413250421457], Player at [-4.0, 0.0, 11.0], Distance = 25.12
# Checking hit: Fireball at [2.845199061428196, 0.0, 35.619203754287234], Player at [-4.0, 0.0, 11.0], Distance = 25.55
# Checking hit: Fireball at [2.7239312489100294, 0.0, 36.1042750043599], Player at [-4.0, 0.0, 11.0], Distance = 25.99
# Checking hit: Fireball at [2.602663436391863, 0.0, 36.58934625443256], Player at [-4.0, 0.0, 11.0], Distance = 26.43
# Checking hit: Fireball at [2.4813956238736963, 0.0, 37.07441750450523], Player at [-4.0, 0.0, 11.0], Distance = 26.87
# Checking hit: Fireball at [9.519238026179588, 0.0, 7.137360563948689], Player at [-4.0, 0.0, 11.0], Distance = 14.06
# Checking hit: Fireball at [2.3601278113555297, 0.0, 37.55948875457789], Player at [-4.0, 0.0, 11.0], Distance = 27.31
# Checking hit: Fireball at [9.038476052359176, 0.0, 7.274721127897378], Player at [-4.0, 0.0, 11.0], Distance = 13.56
# Checking hit: Fireball at [2.238859998837363, 0.0, 38.044560004650556], Player at [-4.0, 0.0, 11.0], Distance = 27.75
# Checking hit: Fireball at [8.557714078538764, 0.0, 7.412081691846066], Player at [-4.0, 0.0, 11.0], Distance = 13.06
# Checking hit: Fireball at [2.1175921863191967, 0.0, 38.52963125472322], Player at [-4.0, 0.0, 11.0], Distance = 28.20
# Checking hit: Fireball at [8.076952104718352, 0.0, 7.549442255794755], Player at [-4.0, 0.0, 11.0], Distance = 12.56
# Checking hit: Fireball at [1.9963243738010301, 0.0, 39.014702504795885], Player at [-4.0, 0.0, 11.0], Distance = 28.65
# Checking hit: Fireball at [7.5961901308979405, 0.0, 7.686802819743444], Player at [-4.0, 0.0, 11.0], Distance = 12.06
# Checking hit: Fireball at [1.8750565612828636, 0.0, 39.49977375486855], Player at [-4.0, 0.0, 11.0], Distance = 29.10
# Checking hit: Fireball at [7.115428157077529, 0.0, 7.824163383692133], Player at [-4.0, 0.0, 11.0], Distance = 11.56
# Checking hit: Fireball at [1.753788748764697, 0.0, 39.984845004941214], Player at [-4.0, 0.0, 11.0], Distance = 29.55
# Checking hit: Fireball at [6.634666183257118, 0.0, 7.9615239476408215], Player at [-4.0, 0.0, 11.0], Distance = 11.06
# Checking hit: Fireball at [1.6325209362465305, 0.0, 40.46991625501388], Player at [-4.0, 0.0, 11.0], Distance = 30.00
# Checking hit: Fireball at [6.153904209436707, 0.0, 8.09888451158951], Player at [-4.0, 0.0, 11.0], Distance = 10.56
# Checking hit: Fireball at [1.511253123728364, 0.0, 40.95498750508654], Player at [-4.0, 0.0, 11.0], Distance = 30.46
# Checking hit: Fireball at [5.673142235616296, 0.0, 8.2362450755382], Player at [-4.0, 0.0, 11.0], Distance = 10.06
# Checking hit: Fireball at [1.3899853112101974, 0.0, 41.44005875515921], Player at [-4.0, 0.0, 11.0], Distance = 30.91
# Checking hit: Fireball at [5.1923802617958845, 0.0, 8.37360563948689], Player at [-4.0, 0.0, 11.0], Distance = 9.56
# Checking hit: Fireball at [1.2687174986920309, 0.0, 41.92513000523187], Player at [-4.0, 0.0, 11.0], Distance = 31.37
# Checking hit: Fireball at [4.711618287975473, 0.0, 8.51096620343558], Player at [-4.0, 0.0, 11.0], Distance = 9.06
# Checking hit: Fireball at [1.1474496861738643, 0.0, 42.410201255304536], Player at [-4.0, 0.0, 11.0], Distance = 31.83
# Checking hit: Fireball at [4.230856314155062, 0.0, 8.648326767384269], Player at [-4.0, 0.0, 11.0], Distance = 8.56
# Checking hit: Fireball at [1.0261818736556978, 0.0, 42.8952725053772], Player at [-4.0, 0.0, 11.0], Distance = 32.29
# Checking hit: Fireball at [3.7500943403346505, 0.0, 8.785687331332959], Player at [-4.0, 0.0, 11.0], Distance = 8.06
# Checking hit: Fireball at [0.9049140611375313, 0.0, 43.380343755449864], Player at [-4.0, 0.0, 11.0], Distance = 32.75
# Checking hit: Fireball at [3.269332366514239, 0.0, 8.923047895281648], Player at [-4.0, 0.0, 11.0], Distance = 7.56
# Checking hit: Fireball at [0.7836462486193647, 0.0, 43.86541500552253], Player at [-4.0, 0.0, 11.0], Distance = 33.21
# Checking hit: Fireball at [2.7885703926938272, 0.0, 9.060408459230338], Player at [-4.0, 0.0, 11.0], Distance = 7.06
# Checking hit: Fireball at [0.6623784361011982, 0.0, 44.35048625559519], Player at [-4.0, 0.0, 11.0], Distance = 33.67
# Checking hit: Fireball at [2.3078084188734156, 0.0, 9.197769023179028], Player at [-4.0, 0.0, 11.0], Distance = 6.56
# Checking hit: Fireball at [0.5411106235830316, 0.0, 44.83555750566786], Player at [-4.0, 0.0, 11.0], Distance = 34.14
# Checking hit: Fireball at [1.827046445053004, 0.0, 9.335129587127717], Player at [-4.0, 0.0, 11.0], Distance = 6.06
# Checking hit: Fireball at [0.41984281106486515, 0.0, 45.32062875574052], Player at [-4.0, 0.0, 10.5], Distance = 35.10
# Checking hit: Fireball at [1.3462844712325923, 0.0, 9.472490151076407], Player at [-4.0, 0.0, 10.5], Distance = 5.44
# Checking hit: Fireball at [0.29857499854669867, 0.0, 45.805700005813186], Player at [-4.0, 0.0, 10.0], Distance = 36.06
# Checking hit: Fireball at [0.8655224974121807, 0.0, 9.609850715025097], Player at [-4.0, 0.0, 10.0], Distance = 4.88
# Checking hit: Fireball at [0.17730718602853218, 0.0, 46.29077125588585], Player at [-4.0, 0.0, 9.5], Distance = 37.03
# Checking hit: Fireball at [0.3847605235917691, 0.0, 9.747211278973786], Player at [-4.0, 0.0, 9.5], Distance = 4.39
# Checking hit: Fireball at [0.0560393735103657, 0.0, 46.775842505958515], Player at [-4.0, 0.0, 9.0], Distance = 37.99
# Checking hit: Fireball at [-0.09600145022864248, 0.0, 9.884571842922476], Player at [-4.0, 0.0, 9.0], Distance = 4.00
# Checking hit: Fireball at [-0.06522843900780079, 0.0, 47.26091375603118], Player at [-4.0, 0.0, 8.5], Distance = 38.96
# Checking hit: Fireball at [-0.576763424049054, 0.0, 10.021932406871166], Player at [-4.0, 0.0, 8.5], Distance = 3.75
# Checking hit: Fireball at [-0.18649625152596727, 0.0, 47.745985006103844], Player at [-4.0, 0.0, 8.0], Distance = 39.93
# Checking hit: Fireball at [-1.0575253978694656, 0.0, 10.159292970819855], Player at [-4.0, 0.0, 8.0], Distance = 3.65
# Checking hit: Fireball at [-0.30776406404413376, 0.0, 48.23105625617651], Player at [-4.0, 0.0, 7.5], Distance = 40.90
# Checking hit: Fireball at [-1.5382873716898773, 0.0, 10.296653534768545], Player at [-4.0, 0.0, 7.5], Distance = 3.73
# Checking hit: Fireball at [-0.42903187656230024, 0.0, 48.71612750624917], Player at [-4.0, 0.0, 7.0], Distance = 41.87
# Checking hit: Fireball at [-2.0190493455102887, 0.0, 10.434014098717235], Player at [-4.0, 0.0, 7.0], Distance = 3.96
# Checking hit: Fireball at [-0.5502996890804668, 0.0, 49.20119875632184], Player at [-4.0, 0.0, 6.5], Distance = 42.84
# Checking hit: Fireball at [-2.4998113193307003, 0.0, 10.571374662665924], Player at [-4.0, 0.0, 6.5], Distance = 4.34
# Checking hit: Fireball at [-0.6715675015986333, 0.0, 49.6862700063945], Player at [-4.0, 0.0, 6.0], Distance = 43.81
# Checking hit: Fireball at [-2.980573293151112, 0.0, 10.708735226614614], Player at [-4.0, 0.0, 6.0], Distance = 4.82
# Checking hit: Fireball at [-3.4613352669715236, 0.0, 10.846095790563304], Player at [-4.0, 0.0, 5.5], Distance = 5.37
# Checking hit: Fireball at [-3.9420972407919352, 0.0, 10.983456354511993], Player at [-4.0, 0.0, 5.0], Distance = 5.98
# Checking hit: Fireball at [-4.422859214612346, 0.0, 11.120816918460683], Player at [-4.0, 0.0, 4.5], Distance = 6.63
# Checking hit: Fireball at [-4.903621188432758, 0.0, 11.258177482409373], Player at [-4.0, 0.0, 4.0], Distance = 7.31
# Checking hit: Fireball at [-5.384383162253169, 0.0, 11.395538046358062], Player at [-4.0, 0.0, 3.5], Distance = 8.02
# Checking hit: Fireball at [-5.86514513607358, 0.0, 11.532898610306752], Player at [-4.0, 0.0, 3.0], Distance = 8.73
# Checking hit: Fireball at [-6.345907109893991, 0.0, 11.670259174255442], Player at [-4.0, 0.0, 2.5], Distance = 9.47
# Checking hit: Fireball at [-6.826669083714402, 0.0, 11.807619738204131], Player at [-4.0, 0.0, 2.0], Distance = 10.21
# Checking hit: Fireball at [-7.307431057534814, 0.0, 11.944980302152821], Player at [-4.0, 0.0, 1.5], Distance = 10.96
# Checking hit: Fireball at [-7.788193031355225, 0.0, 12.08234086610151], Player at [-4.0, 0.0, 1.0], Distance = 11.71
# Checking hit: Fireball at [-8.268955005175636, 0.0, 12.2197014300502], Player at [-4.0, 0.0, 0.5], Distance = 12.47
# Checking hit: Fireball at [-8.749716978996048, 0.0, 12.35706199399889], Player at [-4.0, 0.0, 0.0], Distance = 13.24
# Checking hit: Fireball at [-9.23047895281646, 0.0, 12.49442255794758], Player at [-4.0, 0.0, -0.5], Distance = 14.01
# Checking hit: Fireball at [-9.711240926636872, 0.0, 12.63178312189627], Player at [-4.0, 0.0, -1.0], Distance = 14.78
# Checking hit: Fireball at [-10.192002900457284, 0.0, 12.76914368584496], Player at [-4.0, 0.0, -1.5], Distance = 15.55
# Checking hit: Fireball at [-10.672764874277696, 0.0, 12.906504249793649], Player at [-4.0, 0.0, -2.0], Distance = 16.33
# Checking hit: Fireball at [-11.153526848098108, 0.0, 13.043864813742339], Player at [-4.0, 0.0, -2.0], Distance = 16.66
# Checking hit: Fireball at [-11.63428882191852, 0.0, 13.181225377691028], Player at [-4.0, 0.0, -2.0], Distance = 16.99
# Checking hit: Fireball at [-12.115050795738933, 0.0, 13.318585941639718], Player at [-4.0, 0.0, -2.0], Distance = 17.34
# Checking hit: Fireball at [-12.595812769559345, 0.0, 13.455946505588408], Player at [-4.0, 0.0, -2.0], Distance = 17.69
# Checking hit: Fireball at [-13.076574743379757, 0.0, 13.593307069537097], Player at [-4.0, 0.0, -2.0], Distance = 18.04
# Checking hit: Fireball at [-13.557336717200169, 0.0, 13.730667633485787], Player at [-4.0, 0.0, -2.0], Distance = 18.41
# Checking hit: Fireball at [-14.038098691020581, 0.0, 13.868028197434477], Player at [-4.0, 0.0, -2.0], Distance = 18.78
# Checking hit: Fireball at [-14.518860664840993, 0.0, 14.005388761383166], Player at [-4.0, 0.0, -2.0], Distance = 19.15
# Checking hit: Fireball at [-14.999622638661405, 0.0, 14.142749325331856], Player at [-4.0, 0.0, -2.0], Distance = 19.53
# Checking hit: Fireball at [-15.480384612481817, 0.0, 14.280109889280546], Player at [-4.0, 0.0, -2.0], Distance = 19.92
# Checking hit: Fireball at [-15.96114658630223, 0.0, 14.417470453229235], Player at [-4.0, 0.0, -2.0], Distance = 20.31
# Checking hit: Fireball at [-16.44190856012264, 0.0, 14.554831017177925], Player at [-4.0, 0.0, -2.0], Distance = 20.71
# Checking hit: Fireball at [-16.92267053394305, 0.0, 14.692191581126615], Player at [-4.0, 0.0, -2.0], Distance = 21.11
# Checking hit: Fireball at [-17.403432507763462, 0.0, 14.829552145075304], Player at [-4.0, 0.0, -2.0], Distance = 21.51
# Checking hit: Fireball at [-17.884194481583872, 0.0, 14.966912709023994], Player at [-4.0, 0.0, -2.0], Distance = 21.92
# Checking hit: Fireball at [-18.364956455404283, 0.0, 15.104273272972684], Player at [-4.0, 0.0, -2.0], Distance = 22.34
# Checking hit: Fireball at [-18.845718429224693, 0.0, 15.241633836921373], Player at [-4.0, 0.0, -2.0], Distance = 22.75
# Checking hit: Fireball at [-19.326480403045103, 0.0, 15.378994400870063], Player at [-4.0, 0.0, -2.0], Distance = 23.17
# Checking hit: Fireball at [-19.807242376865513, 0.0, 15.516354964818753], Player at [-4.0, 0.0, -2.0], Distance = 23.59
# Checking hit: Fireball at [9.579410762311722, 0.0, 6.729621204343251], Player at [-4.0, 0.0, -2.0], Distance = 16.14
# Checking hit: Fireball at [-20.288004350685924, 0.0, 15.653715528767442], Player at [-4.0, 0.0, -2.0], Distance = 24.02
# Checking hit: Fireball at [9.158821524623445, 0.0, 6.459242408686501], Player at [-4.0, 0.0, -2.0], Distance = 15.64
# Checking hit: Fireball at [-20.768766324506334, 0.0, 15.791076092716132], Player at [-4.5, 0.0, -2.0], Distance = 24.11
# Checking hit: Fireball at [8.738232286935167, 0.0, 6.188863613029752], Player at [-4.5, 0.0, -2.0], Distance = 15.57
# Checking hit: Fireball at [-21.249528298326744, 0.0, 15.928436656664822], Player at [-5.0, 0.0, -2.0], Distance = 24.20
# Checking hit: Fireball at [8.31764304924689, 0.0, 5.9184848173730025], Player at [-5.0, 0.0, -2.0], Distance = 15.49
# Checking hit: Fireball at [-21.730290272147155, 0.0, 16.06579722061351], Player at [-5.5, 0.0, -2.0], Distance = 24.29
# Checking hit: Fireball at [7.897053811558613, 0.0, 5.648106021716253], Player at [-5.5, 0.0, -2.0], Distance = 15.43
# Checking hit: Fireball at [-22.211052245967565, 0.0, 16.2031577845622], Player at [-6.0, 0.0, -2.0], Distance = 24.38
# Checking hit: Fireball at [7.476464573870336, 0.0, 5.377727226059504], Player at [-6.0, 0.0, -2.0], Distance = 15.36
# Checking hit: Fireball at [-22.691814219787975, 0.0, 16.34051834851089], Player at [-6.5, 0.0, -2.0], Distance = 24.47
# Checking hit: Fireball at [7.055875336182059, 0.0, 5.107348430402754], Player at [-6.5, 0.0, -2.0], Distance = 15.31
# Checking hit: Fireball at [-23.172576193608386, 0.0, 16.47787891245958], Player at [-7.0, 0.0, -2.0], Distance = 24.56
# Checking hit: Fireball at [6.635286098493783, 0.0, 4.836969634746005], Player at [-7.0, 0.0, -2.0], Distance = 15.25
# Checking hit: Fireball at [-23.653338167428796, 0.0, 16.61523947640827], Player at [-7.5, 0.0, -2.0], Distance = 24.65
# Checking hit: Fireball at [6.214696860805506, 0.0, 4.566590839089256], Player at [-7.5, 0.0, -2.0], Distance = 15.21
# Checking hit: Fireball at [-24.134100141249206, 0.0, 16.75260004035696], Player at [-8.0, 0.0, -2.0], Distance = 24.74
# Checking hit: Fireball at [5.794107623117229, 0.0, 4.296212043432506], Player at [-8.0, 0.0, -2.0], Distance = 15.16
# Checking hit: Fireball at [-24.614862115069617, 0.0, 16.88996060430565], Player at [-8.5, 0.0, -2.0], Distance = 24.83
# Checking hit: Fireball at [5.3735183854289525, 0.0, 4.025833247775757], Player at [-8.5, 0.0, -2.0], Distance = 15.13
# Checking hit: Fireball at [-25.095624088890027, 0.0, 17.02732116825434], Player at [-8.5, 0.0, -2.0], Distance = 25.25
# Checking hit: Fireball at [4.952929147740676, 0.0, 3.7554544521190074], Player at [-8.5, 0.0, -2.0], Distance = 14.63
# Checking hit: Fireball at [-25.576386062710437, 0.0, 17.16468173220303], Player at [-8.5, 0.0, -2.0], Distance = 25.67
# Checking hit: Fireball at [4.532339910052399, 0.0, 3.485075656462258], Player at [-8.5, 0.0, -2.0], Distance = 14.14
# Checking hit: Fireball at [-26.057148036530847, 0.0, 17.30204229615172], Player at [-8.5, 0.0, -2.0], Distance = 26.09
# Checking hit: Fireball at [4.111750672364122, 0.0, 3.2146968608055086], Player at [-8.5, 0.0, -2.0], Distance = 13.65
# Checking hit: Fireball at [-26.537910010351258, 0.0, 17.439402860100408], Player at [-8.5, 0.0, -2.0], Distance = 26.52
# Checking hit: Fireball at [3.6911614346758457, 0.0, 2.9443180651487593], Player at [-8.5, 0.0, -2.0], Distance = 13.16
# Checking hit: Fireball at [-27.018671984171668, 0.0, 17.576763424049098], Player at [-8.5, 0.0, -2.0], Distance = 26.95
# Checking hit: Fireball at [3.270572196987569, 0.0, 2.67393926949201], Player at [-8.5, 0.0, -2.0], Distance = 12.66
# Checking hit: Fireball at [-27.49943395799208, 0.0, 17.714123987997787], Player at [-8.5, 0.0, -2.0], Distance = 27.38
# Checking hit: Fireball at [2.8499829592992922, 0.0, 2.4035604738352605], Player at [-8.5, 0.0, -2.0], Distance = 12.17
# Checking hit: Fireball at [-27.98019593181249, 0.0, 17.851484551946477], Player at [-8.5, 0.0, -2.5], Distance = 28.17
# Checking hit: Fireball at [2.4293937216110155, 0.0, 2.133181678178511], Player at [-8.5, 0.0, -2.5], Distance = 11.87
# Checking hit: Fireball at [-28.4609579056329, 0.0, 17.988845115895167], Player at [-8.5, 0.0, -3.0], Distance = 28.97
# Checking hit: Fireball at [2.008804483922739, 0.0, 1.8628028825217617], Player at [-8.5, 0.0, -3.0], Distance = 11.58
# Checking hit: Fireball at [-28.94171987945331, 0.0, 18.126205679843856], Player at [-8.5, 0.0, -3.5], Distance = 29.76
# Checking hit: Fireball at [1.588215246234462, 0.0, 1.5924240868650124], Player at [-8.5, 0.0, -3.5], Distance = 11.30
# Checking hit: Fireball at [-29.42248185327372, 0.0, 18.263566243792546], Player at [-8.5, 0.0, -4.0], Distance = 30.55
# Checking hit: Fireball at [1.1676260085461854, 0.0, 1.322045291208263], Player at [-8.5, 0.0, -4.0], Distance = 11.04
# Checking hit: Fireball at [-29.90324382709413, 0.0, 18.400926807741236], Player at [-8.5, 0.0, -4.5], Distance = 31.35
# Checking hit: Fireball at [0.7470367708579086, 0.0, 1.0516664955515136], Player at [-8.5, 0.0, -4.5], Distance = 10.79
# Checking hit: Fireball at [-30.38400580091454, 0.0, 18.538287371689925], Player at [-8.5, 0.0, -5.0], Distance = 32.14
# Checking hit: Fireball at [0.3264475331696319, 0.0, 0.7812876998947642], Player at [-8.5, 0.0, -5.0], Distance = 10.55
# Checking hit: Fireball at [-30.86476777473495, 0.0, 18.675647935638615], Player at [-8.5, 0.0, -5.5], Distance = 32.93
# Checking hit: Fireball at [-0.0941417045186449, 0.0, 0.5109089042380148], Player at [-8.5, 0.0, -5.5], Distance = 10.33
# Checking hit: Fireball at [-31.34552974855536, 0.0, 18.813008499587305], Player at [-8.5, 0.0, -6.0], Distance = 33.73
# Checking hit: Fireball at [-0.5147309422069217, 0.0, 0.2405301085812655], Player at [-8.5, 0.0, -6.0], Distance = 10.13
# Checking hit: Fireball at [-31.82629172237577, 0.0, 18.950369063535994], Player at [-8.5, 0.0, -6.5], Distance = 34.52
# Checking hit: Fireball at [-0.9353201798951984, 0.0, -0.029848687075483826], Player at [-8.5, 0.0, -6.5], Distance = 9.95
# Checking hit: Fireball at [-32.307053696196185, 0.0, 19.087729627484684], Player at [-8.5, 0.0, -6.5], Distance = 34.95
# Checking hit: Fireball at [-1.3559094175834752, 0.0, -0.30022748273223315], Player at [-8.5, 0.0, -6.5], Distance = 9.46
# Checking hit: Fireball at [-32.7878156700166, 0.0, 19.225090191433374], Player at [-8.5, 0.0, -6.5], Distance = 35.38
# Checking hit: Fireball at [-1.7764986552717519, 0.0, -0.5706062783889825], Player at [-8.5, 0.0, -6.5], Distance = 8.96
# Checking hit: Fireball at [-33.26857764383701, 0.0, 19.362450755382064], Player at [-8.5, 0.0, -6.5], Distance = 35.81
# Checking hit: Fireball at [-2.197087892960029, 0.0, -0.8409850740457319], Player at [-8.5, 0.0, -6.5], Distance = 8.47
# Checking hit: Fireball at [-33.74933961765743, 0.0, 19.499811319330753], Player at [-8.5, 0.0, -6.5], Distance = 36.24
# Checking hit: Fireball at [-2.6176771306483055, 0.0, -1.1113638697024812], Player at [-8.5, 0.0, -6.5], Distance = 7.98
# Checking hit: Fireball at [-34.23010159147784, 0.0, 19.637171883279443], Player at [-8.5, 0.0, -6.5], Distance = 36.68
# Checking hit: Fireball at [-3.0382663683365823, 0.0, -1.3817426653592306], Player at [-8.5, 0.0, -6.5], Distance = 7.49
# Checking hit: Fireball at [-34.710863565298254, 0.0, 19.774532447228133], Player at [-8.5, 0.0, -6.5], Distance = 37.11
# Checking hit: Fireball at [-3.458855606024859, 0.0, -1.65212146101598], Player at [-8.5, 0.0, -6.5], Distance = 6.99
# Checking hit: Fireball at [-35.19162553911867, 0.0, 19.911893011176822], Player at [-8.5, 0.0, -6.5], Distance = 37.55
# Checking hit: Fireball at [-3.8794448437131357, 0.0, -1.9225002566727294], Player at [-8.5, 0.0, -6.5], Distance = 6.50
# Checking hit: Fireball at [-35.67238751293908, 0.0, 20.049253575125512], Player at [-8.5, 0.0, -6.5], Distance = 37.99
# Checking hit: Fireball at [-4.300034081401413, 0.0, -2.1928790523294786], Player at [-8.5, 0.0, -6.5], Distance = 6.02
# Checking hit: Fireball at [-36.153149486759496, 0.0, 20.1866141390742], Player at [-8.5, 0.0, -6.5], Distance = 38.43
# Checking hit: Fireball at [-4.72062331908969, 0.0, -2.463257847986228], Player at [-8.5, 0.0, -6.5], Distance = 5.53
# Checking hit: Fireball at [-36.63391146057991, 0.0, 20.32397470302289], Player at [-8.5, 0.0, -6.5], Distance = 38.87
# Checking hit: Fireball at [-5.141212556777966, 0.0, -2.7336366436429773], Player at [-8.5, 0.0, -6.5], Distance = 5.05
# Checking hit: Fireball at [-37.11467343440032, 0.0, 20.46133526697158], Player at [-8.5, 0.0, -6.5], Distance = 39.32
# Checking hit: Fireball at [-5.561801794466243, 0.0, -3.0040154392997267], Player at [-8.5, 0.0, -6.5], Distance = 4.57
# Checking hit: Fireball at [-37.59543540822074, 0.0, 20.59869583092027], Player at [-8.5, 0.0, -6.5], Distance = 39.76
# Checking hit: Fireball at [-5.98239103215452, 0.0, -3.274394234956476], Player at [-8.5, 0.0, -6.5], Distance = 4.09
# Checking hit: Fireball at [-38.07619738204115, 0.0, 20.73605639486896], Player at [-8.5, 0.0, -6.5], Distance = 40.21
# Checking hit: Fireball at [-6.4029802698427964, 0.0, -3.5447730306132255], Player at [-8.5, 0.0, -6.5], Distance = 3.62
# Checking hit: Fireball at [-38.556959355861565, 0.0, 20.87341695881765], Player at [-8.5, 0.0, -6.5], Distance = 40.65
# Checking hit: Fireball at [-6.823569507531073, 0.0, -3.815151826269975], Player at [-8.5, 0.0, -6.5], Distance = 3.17
# Checking hit: Fireball at [-39.03772132968198, 0.0, 21.01077752276634], Player at [-8.5, 0.0, -6.5], Distance = 41.10
# Checking hit: Fireball at [-7.24415874521935, 0.0, -4.085530621926724], Player at [-8.5, 0.0, -6.5], Distance = 2.72
# Checking hit: Fireball at [-39.51848330350239, 0.0, 21.14813808671503], Player at [-8.5, 0.0, -6.5], Distance = 41.55
# Checking hit: Fireball at [-7.664747982907627, 0.0, -4.355909417583473], Player at [-8.5, 0.0, -6.5], Distance = 2.30
# Checking hit: Fireball at [-39.99924527732281, 0.0, 21.28549865066372], Player at [-8.5, 0.0, -6.5], Distance = 42.00
# Checking hit: Fireball at [-8.085337220595903, 0.0, -4.6262882132402225], Player at [-8.5, 0.0, -6.5], Distance = 1.92
# Checking hit: Fireball at [-40.48000725114322, 0.0, 21.42285921461241], Player at [-8.5, 0.0, -7.0], Distance = 42.79
# Checking hit: Fireball at [-8.505926458284181, 0.0, -4.896667008896972], Player at [-8.5, 0.0, -7.0], Distance = 2.10
# Checking hit: Fireball at [-40.960769224963634, 0.0, 21.5602197785611], Player at [-8.5, 0.0, -7.5], Distance = 43.57
# Checking hit: Fireball at [-8.926515695972459, 0.0, -5.167045804553721], Player at [-8.5, 0.0, -7.5], Distance = 2.37
# Checking hit: Fireball at [-41.44153119878405, 0.0, 21.697580342509788], Player at [-8.5, 0.0, -8.0], Distance = 44.35
# Checking hit: Fireball at [-9.347104933660736, 0.0, -5.437424600210471], Player at [-8.5, 0.0, -8.0], Distance = 2.70
# Checking hit: Fireball at [-41.92229317260446, 0.0, 21.834940906458478], Player at [-8.5, 0.0, -8.5], Distance = 45.14
# Checking hit: Fireball at [-9.767694171349014, 0.0, -5.70780339586722], Player at [-8.5, 0.0, -8.5], Distance = 3.07
# Checking hit: Fireball at [-42.403055146424876, 0.0, 21.972301470407167], Player at [-8.5, 0.0, -8.5], Distance = 45.58
# Checking hit: Fireball at [-10.188283409037291, 0.0, -5.9781821915239695], Player at [-8.5, 0.0, -8.5], Distance = 3.03
# Checking hit: Fireball at [-42.88381712024529, 0.0, 22.109662034355857], Player at [-8.5, 0.0, -8.5], Distance = 46.03
# Checking hit: Fireball at [-10.608872646725569, 0.0, -6.248560987180719], Player at [-8.5, 0.0, -8.5], Distance = 3.08
# Checking hit: Fireball at [-43.364579094065704, 0.0, 22.247022598304547], Player at [-8.5, 0.0, -8.5], Distance = 46.49
# Checking hit: Fireball at [-11.029461884413847, 0.0, -6.518939782837468], Player at [-8.5, 0.0, -8.5], Distance = 3.21
# Checking hit: Fireball at [-43.84534106788612, 0.0, 22.384383162253236], Player at [-8.5, 0.0, -8.5], Distance = 46.94
# Checking hit: Fireball at [-11.450051122102124, 0.0, -6.789318578494218], Player at [-8.5, 0.0, -8.5], Distance = 3.41
# Checking hit: Fireball at [-44.32610304170653, 0.0, 22.521743726201926], Player at [-8.5, 0.0, -8.5], Distance = 47.39
# Checking hit: Fireball at [-11.870640359790402, 0.0, -7.059697374150967], Player at [-8.5, 0.0, -8.5], Distance = 3.67
# Checking hit: Fireball at [-44.806865015526945, 0.0, 22.659104290150616], Player at [-8.5, 0.0, -8.5], Distance = 47.84
# Checking hit: Fireball at [-12.29122959747868, 0.0, -7.330076169807716], Player at [-8.5, 0.0, -8.5], Distance = 3.97
# Checking hit: Fireball at [-45.28762698934736, 0.0, 22.796464854099305], Player at [-8.5, 0.0, -8.5], Distance = 48.30
# Checking hit: Fireball at [-12.711818835166957, 0.0, -7.600454965464466], Player at [-8.5, 0.0, -8.5], Distance = 4.31
# Checking hit: Fireball at [-45.76838896316777, 0.0, 22.933825418047995], Player at [-8.5, 0.0, -8.5], Distance = 48.75
# Checking hit: Fireball at [-13.132408072855235, 0.0, -7.870833761121215], Player at [-8.5, 0.0, -8.5], Distance = 4.67
# Checking hit: Fireball at [-46.24915093698819, 0.0, 23.071185981996685], Player at [-8.5, 0.0, -8.5], Distance = 49.21
# Checking hit: Fireball at [-13.552997310543512, 0.0, -8.141212556777964], Player at [-8.5, 0.0, -8.5], Distance = 5.07
# Checking hit: Fireball at [-46.7299129108086, 0.0, 23.208546545945374], Player at [-8.5, 0.0, -8.5], Distance = 49.67
# Checking hit: Fireball at [-13.97358654823179, 0.0, -8.411591352434712], Player at [-8.5, 0.0, -8.5], Distance = 5.47
# Checking hit: Fireball at [-47.210674884629015, 0.0, 23.345907109894064], Player at [-8.5, 0.0, -8.5], Distance = 50.13
# Checking hit: Fireball at [-14.394175785920067, 0.0, -8.68197014809146], Player at [-8.5, 0.0, -8.5], Distance = 5.90
# Checking hit: Fireball at [-47.69143685844943, 0.0, 23.483267673842754], Player at [-8.5, 0.0, -8.5], Distance = 50.59
# Checking hit: Fireball at [-14.814765023608345, 0.0, -8.952348943748209], Player at [-8.5, 0.0, -8.5], Distance = 6.33
# Checking hit: Fireball at [-48.17219883226984, 0.0, 23.620628237791443], Player at [-8.5, 0.0, -8.5], Distance = 51.05
# Checking hit: Fireball at [-15.235354261296623, 0.0, -9.222727739404958], Player at [-8.5, 0.0, -8.5], Distance = 6.77
# Checking hit: Fireball at [-48.652960806090256, 0.0, 23.757988801740133], Player at [-8.5, 0.0, -8.5], Distance = 51.51
# Checking hit: Fireball at [-15.6559434989849, 0.0, -9.493106535061706], Player at [-8.5, 0.0, -8.5], Distance = 7.22
# Checking hit: Fireball at [-49.13372277991067, 0.0, 23.895349365688823], Player at [-8.5, 0.0, -8.5], Distance = 51.97
# Checking hit: Fireball at [-16.076532736673176, 0.0, -9.763485330718455], Player at [-8.5, 0.0, -8.5], Distance = 7.68
# Checking hit: Fireball at [9.616739759409919, 0.0, 6.6788900686947965], Player at [-8.5, 0.0, -8.5], Distance = 23.64
# Checking hit: Fireball at [-49.614484753731084, 0.0, 24.032709929637512], Player at [-8.5, 0.0, -8.5], Distance = 52.43
# Checking hit: Fireball at [-16.497121974361452, 0.0, -10.033864126375203], Player at [-8.5, 0.0, -8.5], Distance = 8.14
# Checking hit: Fireball at [9.233479518819838, 0.0, 6.357780137389593], Player at [-8.5, 0.0, -8.5], Distance = 23.14
# Checking hit: Fireball at [-16.917711212049728, 0.0, -10.304242922031952], Player at [-8.5, 0.0, -8.5], Distance = 8.61
# Checking hit: Fireball at [8.850219278229757, 0.0, 6.0366702060843895], Player at [-8.5, 0.0, -8.5], Distance = 22.64
# Checking hit: Fireball at [-17.338300449738004, 0.0, -10.5746217176887], Player at [-8.5, 0.0, -8.5], Distance = 9.08
# Checking hit: Fireball at [8.466959037639676, 0.0, 5.715560274779186], Player at [-8.5, 0.0, -8.5], Distance = 22.14
# Checking hit: Fireball at [-17.75888968742628, 0.0, -10.845000513345449], Player at [-8.5, 0.0, -8.5], Distance = 9.55
# Checking hit: Fireball at [8.083698797049594, 0.0, 5.394450343473983], Player at [-8.5, 0.0, -8.5], Distance = 21.64
# Checking hit: Fireball at [-18.179478925114555, 0.0, -11.115379309002197], Player at [-8.5, 0.0, -8.5], Distance = 10.03
# Checking hit: Fireball at [7.700438556459512, 0.0, 5.073340412168779], Player at [-8.5, 0.0, -8.5], Distance = 21.14
# Checking hit: Fireball at [-18.60006816280283, 0.0, -11.385758104658946], Player at [-8.5, 0.0, -8.5], Distance = 10.50
# Checking hit: Fireball at [7.31717831586943, 0.0, 4.752230480863576], Player at [-8.5, 0.0, -8.5], Distance = 20.64
# Checking hit: Fireball at [-19.020657400491107, 0.0, -11.656136900315694], Player at [-8.5, 0.0, -8.5], Distance = 10.98
# Checking hit: Fireball at [6.933918075279348, 0.0, 4.431120549558372], Player at [-8.5, 0.0, -8.5], Distance = 20.14
# Checking hit: Fireball at [-19.441246638179383, 0.0, -11.926515695972443], Player at [-8.5, 0.0, -8.5], Distance = 11.47
# Checking hit: Fireball at [6.550657834689266, 0.0, 4.110010618253169], Player at [-8.5, 0.0, -8.5], Distance = 19.64
# Checking hit: Fireball at [-19.86183587586766, 0.0, -12.196894491629191], Player at [-8.5, 0.0, -8.5], Distance = 11.95
# Checking hit: Fireball at [6.167397594099184, 0.0, 3.788900686947965], Player at [-8.5, 0.0, -8.5], Distance = 19.14
# Checking hit: Fireball at [-20.282425113555934, 0.0, -12.46727328728594], Player at [-8.5, 0.0, -8.5], Distance = 12.43
# Checking hit: Fireball at [5.784137353509102, 0.0, 3.4677907556427616], Player at [-8.5, 0.0, -8.5], Distance = 18.64
# Checking hit: Fireball at [-20.70301435124421, 0.0, -12.737652082942688], Player at [-8.5, 0.0, -8.5], Distance = 12.92
# Checking hit: Fireball at [5.40087711291902, 0.0, 3.146680824337558], Player at [-8.5, 0.0, -8.5], Distance = 18.14
# Checking hit: Fireball at [-21.123603588932486, 0.0, -13.008030878599437], Player at [-8.5, 0.0, -8.5], Distance = 13.40
# Checking hit: Fireball at [5.017616872328938, 0.0, 2.8255708930323546], Player at [-8.5, 0.0, -8.5], Distance = 17.64
# Checking hit: Fireball at [-21.544192826620762, 0.0, -13.278409674256185], Player at [-8.5, 0.0, -8.5], Distance = 13.89
# Checking hit: Fireball at [4.634356631738856, 0.0, 2.504460961727151], Player at [-8.5, 0.0, -8.5], Distance = 17.14
# Checking hit: Fireball at [-21.964782064309038, 0.0, -13.548788469912934], Player at [-8.5, 0.0, -8.5], Distance = 14.38
# Checking hit: Fireball at [4.251096391148774, 0.0, 2.1833510304219477], Player at [-8.5, 0.0, -8.5], Distance = 16.64
# Checking hit: Fireball at [-22.385371301997314, 0.0, -13.819167265569682], Player at [-8.5, 0.0, -8.5], Distance = 14.87
# Checking hit: Fireball at [3.8678361505586922, 0.0, 1.862241099116744], Player at [-8.5, 0.0, -8.5], Distance = 16.14
# Checking hit: Fireball at [-22.80596053968559, 0.0, -14.08954606122643], Player at [-8.5, 0.0, -8.5], Distance = 15.36
# Checking hit: Fireball at [3.48457590996861, 0.0, 1.5411311678115402], Player at [-8.5, 0.0, -8.5], Distance = 15.64
# Checking hit: Fireball at [-23.226549777373865, 0.0, -14.359924856883179], Player at [-8.5, 0.0, -8.5], Distance = 15.85
# Checking hit: Fireball at [3.101315669378528, 0.0, 1.2200212365063365], Player at [-8.5, 0.0, -8.5], Distance = 15.14
# Checking hit: Fireball at [-23.64713901506214, 0.0, -14.630303652539927], Player at [-8.5, 0.0, -8.5], Distance = 16.34
# Checking hit: Fireball at [2.718055428788446, 0.0, 0.8989113052011328], Player at [-8.5, 0.0, -8.5], Distance = 14.64
# Checking hit: Fireball at [-24.067728252750417, 0.0, -14.900682448196676], Player at [-8.5, 0.0, -8.5], Distance = 16.83
# Checking hit: Fireball at [2.334795188198364, 0.0, 0.5778013738959291], Player at [-8.5, 0.0, -8.5], Distance = 14.14
# Checking hit: Fireball at [-24.488317490438693, 0.0, -15.171061243853424], Player at [-8.5, 0.0, -8.5], Distance = 17.32
# Checking hit: Fireball at [1.9515349476082824, 0.0, 0.25669144259072546], Player at [-8.5, 0.0, -8.5], Distance = 13.64
# Checking hit: Fireball at [-24.90890672812697, 0.0, -15.441440039510173], Player at [-8.5, 0.0, -8.5], Distance = 17.82
# Checking hit: Fireball at [1.5682747070182006, 0.0, -0.0644184887144782], Player at [-8.5, 0.0, -8.5], Distance = 13.14
# Checking hit: Fireball at [-25.329495965815244, 0.0, -15.711818835166921], Player at [-8.5, 0.0, -8.5], Distance = 18.31
# Checking hit: Fireball at [1.1850144664281188, 0.0, -0.38552842001968185], Player at [-8.5, 0.0, -8.5], Distance = 12.64
# Checking hit: Fireball at [-25.75008520350352, 0.0, -15.98219763082367], Player at [-8.5, 0.0, -8.5], Distance = 18.80
# Checking hit: Fireball at [0.801754225838037, 0.0, -0.7066383513248855], Player at [-8.5, 0.0, -8.5], Distance = 12.14
# Checking hit: Fireball at [-26.170674441191796, 0.0, -16.25257642648042], Player at [-8.5, 0.0, -8.5], Distance = 19.30
# Checking hit: Fireball at [0.4184939852479552, 0.0, -1.0277482826300892], Player at [-8.5, 0.0, -8.5], Distance = 11.64
# Checking hit: Fireball at [-26.591263678880072, 0.0, -16.52295522213717], Player at [-8.5, 0.0, -8.5], Distance = 19.79
# Checking hit: Fireball at [0.035233744657873434, 0.0, -1.348858213935293], Player at [-8.5, 0.0, -8.5], Distance = 11.14
# Checking hit: Fireball at [-27.011852916568348, 0.0, -16.79333401779392], Player at [-8.5, 0.0, -8.5], Distance = 20.28
# Checking hit: Fireball at [-0.34802649593220836, 0.0, -1.6699681452404966], Player at [-8.5, 0.0, -8.5], Distance = 10.64
# Checking hit: Fireball at [-27.432442154256623, 0.0, -17.06371281345067], Player at [-8.5, 0.0, -8.5], Distance = 20.78
# Checking hit: Fireball at [-0.7312867365222901, 0.0, -1.9910780765457003], Player at [-8.5, 0.0, -8.5], Distance = 10.14
# Checking hit: Fireball at [-27.8530313919449, 0.0, -17.33409160910742], Player at [-8.5, 0.0, -8.5], Distance = 21.27
# Checking hit: Fireball at [-1.114546977112372, 0.0, -2.312188007850904], Player at [-8.5, 0.0, -8.5], Distance = 9.64
# Checking hit: Fireball at [-28.273620629633175, 0.0, -17.60447040476417], Player at [-8.5, 0.0, -8.5], Distance = 21.77
# Checking hit: Fireball at [-1.4978072177024537, 0.0, -2.6332979391561073], Player at [-8.5, 0.0, -8.5], Distance = 9.14
# Checking hit: Fireball at [-28.69420986732145, 0.0, -17.874849200420922], Player at [-8.5, 0.0, -8.5], Distance = 22.26
# Checking hit: Fireball at [-1.8810674582925355, 0.0, -2.954407870461311], Player at [-8.5, 0.0, -8.5], Distance = 8.64
# Checking hit: Fireball at [-29.114799105009727, 0.0, -18.145227996077672], Player at [-8.5, 0.0, -8.5], Distance = 22.76
# Checking hit: Fireball at [-2.2643276988826173, 0.0, -3.2755178017665143], Player at [-8.5, 0.0, -8.5], Distance = 8.14
# Checking hit: Fireball at [-29.535388342698003, 0.0, -18.415606791734422], Player at [-9.0, 0.0, -8.5], Distance = 22.80
# Checking hit: Fireball at [-2.6475879394726993, 0.0, -3.596627733071718], Player at [-9.0, 0.0, -8.5], Distance = 8.02
# Checking hit: Fireball at [-29.95597758038628, 0.0, -18.685985587391173], Player at [-9.5, 0.0, -8.5], Distance = 22.85
# Checking hit: Fireball at [-3.0308481800627813, 0.0, -3.9177376643769213], Player at [-9.5, 0.0, -8.5], Distance = 7.93
# Checking hit: Fireball at [-30.376566818074554, 0.0, -18.956364383047923], Player at [-10.0, 0.0, -8.5], Distance = 22.90
# Checking hit: Fireball at [-3.4141084206528634, 0.0, -4.238847595682125], Player at [-10.0, 0.0, -8.5], Distance = 7.84
# Checking hit: Fireball at [-30.79715605576283, 0.0, -19.226743178704673], Player at [-10.5, 0.0, -8.5], Distance = 22.96
# Checking hit: Fireball at [-3.7973686612429454, 0.0, -4.559957526987328], Player at [-10.5, 0.0, -8.5], Distance = 7.77
# Checking hit: Fireball at [-31.217745293451106, 0.0, -19.497121974361423], Player at [-11.0, 0.0, -8.5], Distance = 23.02
# Checking hit: Fireball at [-4.180628901833027, 0.0, -4.881067458292532], Player at [-11.0, 0.0, -8.5], Distance = 7.72
# Checking hit: Fireball at [-31.63833453113938, 0.0, -19.767500770018174], Player at [-11.5, 0.0, -8.5], Distance = 23.08
# Checking hit: Fireball at [-4.563889142423109, 0.0, -5.202177389597735], Player at [-11.5, 0.0, -8.5], Distance = 7.68
# Checking hit: Fireball at [-32.05892376882766, 0.0, -20.037879565674924], Player at [-12.0, 0.0, -8.5], Distance = 23.14
# Checking hit: Fireball at [-4.947149383013191, 0.0, -5.523287320902939], Player at [-12.0, 0.0, -8.5], Distance = 7.66
# Checking hit: Fireball at [-32.47951300651594, 0.0, -20.308258361331674], Player at [-12.0, 0.0, -8.5], Distance = 23.64
# Checking hit: Fireball at [-5.330409623603273, 0.0, -5.844397252208142], Player at [-12.0, 0.0, -8.5], Distance = 7.18
# Checking hit: Fireball at [-32.90010224420421, 0.0, -20.578637156988425], Player at [-12.0, 0.0, -8.5], Distance = 24.14
# Checking hit: Fireball at [-5.713669864193355, 0.0, -6.165507183513346], Player at [-12.0, 0.0, -8.5], Distance = 6.71
# Checking hit: Fireball at [-33.32069148189249, 0.0, -20.849015952645175], Player at [-12.0, 0.0, -8.5], Distance = 24.64
# Checking hit: Fireball at [-6.096930104783437, 0.0, -6.486617114818549], Player at [-12.0, 0.0, -8.5], Distance = 6.24
# Checking hit: Fireball at [-33.741280719580764, 0.0, -21.119394748301925], Player at [-12.0, 0.0, -8.5], Distance = 25.14
# Checking hit: Fireball at [-6.4801903453735195, 0.0, -6.807727046123753], Player at [-12.0, 0.0, -8.5], Distance = 5.77
# Checking hit: Fireball at [-34.16186995726904, 0.0, -21.389773543958675], Player at [-12.0, 0.0, -8.5], Distance = 25.64
# Checking hit: Fireball at [-6.8634505859636015, 0.0, -7.128836977428956], Player at [-12.0, 0.0, -8.5], Distance = 5.32
# Checking hit: Fireball at [-34.582459194957316, 0.0, -21.660152339615426], Player at [-12.0, 0.0, -8.5], Distance = 26.14
# Checking hit: Fireball at [-7.2467108265536835, 0.0, -7.44994690873416], Player at [-12.0, 0.0, -8.5], Distance = 4.87
# Checking hit: Fireball at [-35.00304843264559, 0.0, -21.930531135272176], Player at [-12.0, 0.0, -8.5], Distance = 26.64
# Checking hit: Fireball at [-7.6299710671437655, 0.0, -7.771056840039363], Player at [-12.0, 0.0, -8.5], Distance = 4.43
# Checking hit: Fireball at [-35.42363767033387, 0.0, -22.200909930928926], Player at [-12.0, 0.0, -8.5], Distance = 27.14
# Checking hit: Fireball at [-8.013231307733847, 0.0, -8.092166771344568], Player at [-12.0, 0.0, -8.5], Distance = 4.01
# Checking hit: Fireball at [-35.844226908022144, 0.0, -22.471288726585676], Player at [-12.0, 0.0, -8.5], Distance = 27.64
# Checking hit: Fireball at [-8.396491548323928, 0.0, -8.413276702649771], Player at [-12.0, 0.0, -8.5], Distance = 3.60
# Checking hit: Fireball at [-36.26481614571042, 0.0, -22.741667522242427], Player at [-12.0, 0.0, -8.5], Distance = 28.14
# Checking hit: Fireball at [-8.779751788914009, 0.0, -8.734386633954974], Player at [-12.0, 0.0, -8.5], Distance = 3.23
# Checking hit: Fireball at [-36.685405383398695, 0.0, -23.012046317899177], Player at [-12.0, 0.0, -8.5], Distance = 28.64
# Checking hit: Fireball at [-9.16301202950409, 0.0, -9.055496565260178], Player at [-12.0, 0.0, -8.5], Distance = 2.89
# Checking hit: Fireball at [-37.10599462108697, 0.0, -23.282425113555927], Player at [-12.0, 0.0, -8.5], Distance = 29.13
# Checking hit: Fireball at [-9.546272270094171, 0.0, -9.376606496565381], Player at [-12.0, 0.0, -8.5], Distance = 2.61
# Checking hit: Fireball at [-37.52658385877525, 0.0, -23.552803909212678], Player at [-12.0, 0.0, -8.5], Distance = 29.63
# Checking hit: Fireball at [-9.929532510684252, 0.0, -9.697716427870585], Player at [-12.0, 0.0, -8.5], Distance = 2.39
# Checking hit: Fireball at [-37.94717309646352, 0.0, -23.823182704869428], Player at [-12.0, 0.0, -8.5], Distance = 30.13
# Checking hit: Fireball at [-10.312792751274333, 0.0, -10.018826359175788], Player at [-12.0, 0.0, -8.5], Distance = 2.27
# Checking hit: Fireball at [-38.3677623341518, 0.0, -24.093561500526178], Player at [-12.0, 0.0, -8.5], Distance = 30.63
# Checking hit: Fireball at [-10.696052991864414, 0.0, -10.339936290480992], Player at [-12.0, 0.0, -8.5], Distance = 2.26
# Checking hit: Fireball at [-38.788351571840074, 0.0, -24.36394029618293], Player at [-12.0, 0.0, -8.5], Distance = 31.13
# Checking hit: Fireball at [-11.079313232454496, 0.0, -10.661046221786195], Player at [-12.0, 0.0, -8.5], Distance = 2.35
# Checking hit: Fireball at [-39.20894080952835, 0.0, -24.63431909183968], Player at [-12.0, 0.0, -8.5], Distance = 31.63
# Checking hit: Fireball at [-11.462573473044577, 0.0, -10.982156153091399], Player at [-12.0, 0.0, -8.5], Distance = 2.54
# Checking hit: Fireball at [-39.629530047216626, 0.0, -24.90469788749643], Player at [-12.0, 0.0, -8.5], Distance = 32.13
# Checking hit: Fireball at [-11.845833713634658, 0.0, -11.303266084396602], Player at [-12.0, 0.0, -8.5], Distance = 2.81
# Checking hit: Fireball at [-40.0501192849049, 0.0, -25.17507668315318], Player at [-12.0, 0.0, -9.0], Distance = 32.38
# Checking hit: Fireball at [-12.229093954224739, 0.0, -11.624376015701806], Player at [-12.0, 0.0, -9.0], Distance = 2.63
# Checking hit: Fireball at [-40.47070852259318, 0.0, -25.44545547880993], Player at [-12.0, 0.0, -9.5], Distance = 32.63
# Checking hit: Fireball at [-12.61235419481482, 0.0, -11.94548594700701], Player at [-12.0, 0.0, -9.5], Distance = 2.52
# Checking hit: Fireball at [-40.891297760281454, 0.0, -25.71583427446668], Player at [-12.0, 0.0, -10.0], Distance = 32.89
# Checking hit: Fireball at [-12.995614435404901, 0.0, -12.266595878312213], Player at [-12.0, 0.0, -10.0], Distance = 2.48
# Checking hit: Fireball at [-41.31188699796973, 0.0, -25.98621307012343], Player at [-12.0, 0.0, -10.5], Distance = 33.15
# Checking hit: Fireball at [-13.378874675994982, 0.0, -12.587705809617416], Player at [-12.0, 0.0, -10.5], Distance = 2.50
# Checking hit: Fireball at [-41.732476235658005, 0.0, -26.25659186578018], Player at [-12.0, 0.0, -11.0], Distance = 33.42
# Checking hit: Fireball at [-13.762134916585063, 0.0, -12.90881574092262], Player at [-12.0, 0.0, -11.0], Distance = 2.60
# Checking hit: Fireball at [9.61302135039834, 0.0, 6.683381104871368], Player at [-12.0, 0.0, -11.0], Distance = 27.93
# Checking hit: Fireball at [-42.15306547334628, 0.0, -26.52697066143693], Player at [-12.0, 0.0, -11.5], Distance = 33.69
# Checking hit: Fireball at [-14.145395157175145, 0.0, -13.229925672227823], Player at [-12.0, 0.0, -11.5], Distance = 2.76
# Checking hit: Fireball at [9.226042700796679, 0.0, 6.3667622097427365], Player at [-12.0, 0.0, -11.5], Distance = 27.74
# Checking hit: Fireball at [-42.57365471103456, 0.0, -26.79734945709368], Player at [-12.0, 0.0, -12.0], Distance = 33.97
# Checking hit: Fireball at [-14.528655397765226, 0.0, -13.551035603533027], Player at [-12.0, 0.0, -12.0], Distance = 2.97
# Checking hit: Fireball at [8.839064051195018, 0.0, 6.050143314614105], Player at [-12.0, 0.0, -12.0], Distance = 27.57
# ...
# Checking hit: Fireball at [-47.20013632560559, 0.0, -29.771516209317934], Player at [-12.0, 0.0, -12.5], Distance = 39.21
# Checking hit: Fireball at [-18.744518044256132, 0.0, -17.08324484789027], Player at [-12.0, 0.0, -12.5], Distance = 8.15
# Checking hit: Fireball at [4.582298905576753, 0.0, 2.567335468199158], Player at [-12.0, 0.0, -12.5], Distance = 22.41
# Checking hit: Fireball at [-47.62072556329387, 0.0, -30.041895004974684], Player at [-12.0, 0.0, -12.5], Distance = 39.71
# Checking hit: Fireball at [-19.127778284846215, 0.0, -17.404354779195476], Player at [-12.0, 0.0, -12.5], Distance = 8.65
# Checking hit: Fireball at [4.195320255975092, 0.0, 2.2507165730705267], Player at [-12.0, 0.0, -12.5], Distance = 21.91
# Checking hit: Fireball at [-48.04131480098214, 0.0, -30.312273800631434], Player at [-12.0, 0.0, -12.5], Distance = 40.20
# Checking hit: Fireball at [-19.511038525436298, 0.0, -17.72546471050068], Player at [-12.0, 0.0, -12.5], Distance = 9.15
# Checking hit: Fireball at [3.808341606373432, 0.0, 1.9340976779418955], Player at [-12.0, 0.0, -12.5], Distance = 21.41
# Checking hit: Fireball at [-48.46190403867042, 0.0, -30.582652596288185], Player at [-12.0, 0.0, -12.5], Distance = 40.70
# Checking hit: Fireball at [-19.89429876602638, 0.0, -18.046574641805886], Player at [-12.0, 0.0, -12.5], Distance = 9.65
# Checking hit: Fireball at [3.4213629567717714, 0.0, 1.6174787828132642], Player at [-12.0, 0.0, -12.5], Distance = 20.91
# Checking hit: Fireball at [-48.882493276358694, 0.0, -30.853031391944935], Player at [-12.0, 0.0, -12.5], Distance = 41.20
# Checking hit: Fireball at [-20.277559006616464, 0.0, -18.36768457311109], Player at [-12.0, 0.0, -12.5], Distance = 10.15
# Checking hit: Fireball at [3.034384307170111, 0.0, 1.300859887684633], Player at [-12.0, 0.0, -12.5], Distance = 20.41
# Checking hit: Fireball at [-49.30308251404697, 0.0, -31.123410187601685], Player at [-12.0, 0.0, -12.5], Distance = 41.69
# Checking hit: Fireball at [-20.660819247206547, 0.0, -18.688794504416297], Player at [-12.0, 0.0, -12.5], Distance = 10.64
# Checking hit: Fireball at [2.6474056575684504, 0.0, 0.9842409925560016], Player at [-12.0, 0.0, -12.5], Distance = 19.91
# Checking hit: Fireball at [-49.723671751735246, 0.0, -31.393788983258435], Player at [-12.0, 0.0, -12.5], Distance = 42.19
# Checking hit: Fireball at [-21.04407948779663, 0.0, -19.009904435721502], Player at [-12.0, 0.0, -12.5], Distance = 11.14
# Checking hit: Fireball at [2.26042700796679, 0.0, 0.6676220974273703], Player at [-12.0, 0.0, -12.5], Distance = 19.41
# Checking hit: Fireball at [-21.427339728386713, 0.0, -19.331014367026707], Player at [-12.0, 0.0, -12.5], Distance = 11.64
# Checking hit: Fireball at [1.8734483583651294, 0.0, 0.351003202298739], Player at [-12.0, 0.0, -12.5], Distance = 18.91
# Checking hit: Fireball at [-21.810599968976796, 0.0, -19.652124298331913], Player at [-12.0, 0.0, -12.5], Distance = 12.14
# Checking hit: Fireball at [1.4864697087634688, 0.0, 0.03438430717010765], Player at [-12.0, 0.0, -12.5], Distance = 18.41
# Checking hit: Fireball at [-22.19386020956688, 0.0, -19.973234229637118], Player at [-12.0, 0.0, -12.5], Distance = 12.64
# Checking hit: Fireball at [1.0994910591618083, 0.0, -0.2822345879585237], Player at [-12.0, 0.0, -12.5], Distance = 17.91
# Checking hit: Fireball at [-22.57712045015696, 0.0, -20.294344160942323], Player at [-11.5, 0.0, -12.5], Distance = 13.54
# Checking hit: Fireball at [0.7125124095601478, 0.0, -0.598853483087155], Player at [-11.5, 0.0, -12.5], Distance = 17.05
# Checking hit: Fireball at [-22.960380690747044, 0.0, -20.61545409224753], Player at [-11.0, 0.0, -12.5], Distance = 14.45
# Checking hit: Fireball at [0.3255337599584873, 0.0, -0.9154723782157863], Player at [-11.0, 0.0, -12.5], Distance = 16.20
# Checking hit: Fireball at [-23.343640931337127, 0.0, -20.936564023552734], Player at [-10.5, 0.0, -12.5], Distance = 15.37
# Checking hit: Fireball at [-0.061444889643173184, 0.0, -1.2320912733444176], Player at [-10.5, 0.0, -12.5], Distance = 15.36
# Checking hit: Fireball at [-23.72690117192721, 0.0, -21.25767395485794], Player at [-10.0, 0.0, -12.5], Distance = 16.28
# Checking hit: Fireball at [-0.4484235392448337, 0.0, -1.5487101684730489], Player at [-10.0, 0.0, -12.5], Distance = 14.53
# Checking hit: Fireball at [-24.110161412517293, 0.0, -21.578783886163144], Player at [-9.5, 0.0, -12.5], Distance = 17.20
# Checking hit: Fireball at [-0.8354021888464942, 0.0, -1.8653290636016802], Player at [-9.5, 0.0, -12.5], Distance = 13.72
# Checking hit: Fireball at [-24.493421653107376, 0.0, -21.89989381746835], Player at [-9.0, 0.0, -12.5], Distance = 18.12
# Checking hit: Fireball at [-1.2223808384481547, 0.0, -2.1819479587303117], Player at [-9.0, 0.0, -12.5], Distance = 12.92
# Checking hit: Fireball at [-24.87668189369746, 0.0, -22.221003748773555], Player at [-9.0, 0.0, -12.5], Distance = 18.62
# Checking hit: Fireball at [-1.6093594880498152, 0.0, -2.498566853858943], Player at [-9.0, 0.0, -12.5], Distance = 12.44
# Checking hit: Fireball at [-25.25994213428754, 0.0, -22.54211368007876], Player at [-9.0, 0.0, -12.5], Distance = 19.11
# Checking hit: Fireball at [-1.9963381376514757, 0.0, -2.8151857489875742], Player at [-9.0, 0.0, -12.5], Distance = 11.95
# Checking hit: Fireball at [-25.643202374877625, 0.0, -22.863223611383965], Player at [-9.0, 0.0, -12.5], Distance = 19.61
# Checking hit: Fireball at [-2.3833167872531362, 0.0, -3.1318046441162055], Player at [-9.0, 0.0, -12.5], Distance = 11.47
# Checking hit: Fireball at [-26.026462615467707, 0.0, -23.18433354268917], Player at [-9.0, 0.0, -12.5], Distance = 20.10
# Checking hit: Fireball at [-2.7702954368547967, 0.0, -3.448423539244837], Player at [-9.0, 0.0, -12.5], Distance = 10.99
# Checking hit: Fireball at [-26.40972285605779, 0.0, -23.505443473994376], Player at [-9.0, 0.0, -12.5], Distance = 20.60
# Checking hit: Fireball at [-3.1572740864564572, 0.0, -3.765042434373468], Player at [-9.0, 0.0, -12.5], Distance = 10.51
# Checking hit: Fireball at [-26.792983096647873, 0.0, -23.82655340529958], Player at [-9.0, 0.0, -12.5], Distance = 21.09
# Checking hit: Fireball at [-3.5442527360581177, 0.0, -4.0816613295021], Player at [-9.0, 0.0, -12.5], Distance = 10.03
# Checking hit: Fireball at [-27.176243337237956, 0.0, -24.147663336604786], Player at [-9.0, 0.0, -12.5], Distance = 21.59
# Checking hit: Fireball at [-3.9312313856597783, 0.0, -4.3982802246307315], Player at [-9.0, 0.0, -12.5], Distance = 9.56
# Checking hit: Fireball at [-27.55950357782804, 0.0, -24.46877326790999], Player at [-9.0, 0.0, -12.5], Distance = 22.08
# Checking hit: Fireball at [-4.318210035261439, 0.0, -4.714899119759363], Player at [-9.0, 0.0, -12.5], Distance = 9.08
# Checking hit: Fireball at [-27.942763818418122, 0.0, -24.789883199215197], Player at [-9.0, 0.0, -12.5], Distance = 22.58
# Checking hit: Fireball at [-4.705188684863099, 0.0, -5.031518014887995], Player at [-9.0, 0.0, -12.5], Distance = 8.62
# Checking hit: Fireball at [-28.326024059008205, 0.0, -25.110993130520402], Player at [-9.0, 0.0, -12.5], Distance = 23.08
# Checking hit: Fireball at [-5.09216733446476, 0.0, -5.348136910016627], Player at [-9.0, 0.0, -12.5], Distance = 8.15
# Checking hit: Fireball at [-28.709284299598288, 0.0, -25.432103061825607], Player at [-9.0, 0.0, -12.5], Distance = 23.57
# Checking hit: Fireball at [-5.47914598406642, 0.0, -5.6647558051452584], Player at [-9.0, 0.0, -12.5], Distance = 7.69
# Checking hit: Fireball at [-29.09254454018837, 0.0, -25.753212993130813], Player at [-9.0, 0.0, -12.0], Distance = 24.35
# Checking hit: Fireball at [-5.866124633668081, 0.0, -5.98137470027389], Player at [-9.0, 0.0, -12.0], Distance = 6.79
# Checking hit: Fireball at [-29.475804780778454, 0.0, -26.074322924436018], Player at [-9.0, 0.0, -11.5], Distance = 25.13
# Checking hit: Fireball at [-6.253103283269741, 0.0, -6.297993595402522], Player at [-9.0, 0.0, -11.5], Distance = 5.88
# 🏁 Player Wins!
# Checking hit: Fireball at [-29.859065021368536, 0.0, -26.395432855741223], Player at [-9.0, 0.0, -11.0], Distance = 25.93
# Checking hit: Fireball at [-6.640081932871402, 0.0, -6.614612490531154], Player at [-9.0, 0.0, -11.0], Distance = 4.98
# Checking hit: Fireball at [-30.24232526195862, 0.0, -26.71654278704643], Player at [-9.0, 0.0, -10.5], Distance = 26.72
# Checking hit: Fireball at [-7.027060582473062, 0.0, -6.931231385659785], Player at [-9.0, 0.0, -10.5], Distance = 4.08
# Checking hit: Fireball at [-30.625585502548702, 0.0, -27.037652718351634], Player at [-9.0, 0.0, -10.0], Distance = 27.53
# Checking hit: Fireball at [-7.414039232074723, 0.0, -7.247850280788417], Player at [-9.0, 0.0, -10.0], Distance = 3.18
# Checking hit: Fireball at [-31.008845743138785, 0.0, -27.35876264965684], Player at [-9.0, 0.0, -9.5], Distance = 28.34
# Checking hit: Fireball at [-7.801017881676383, 0.0, -7.564469175917049], Player at [-9.0, 0.0, -9.5], Distance = 2.28
# Checking hit: Fireball at [-31.392105983728868, 0.0, -27.679872580962044], Player at [-9.0, 0.0, -9.0], Distance = 29.16
# Checking hit: Fireball at [-8.187996531278044, 0.0, -7.8810880710456805], Player at [-9.0, 0.0, -9.0], Distance = 1.38
# Checking hit: Fireball at [-31.77536622431895, 0.0, -28.00098251226725], Player at [-9.0, 0.0, -8.5], Distance = 29.98
# Checking hit: Fireball at [-8.574975180879704, 0.0, -8.197706966174312], Player at [-9.0, 0.0, -8.5], Distance = 0.52
# 🔥 Player hit! Health: 4
# Checking hit: Fireball at [-32.158626464909034, 0.0, -28.322092443572455], Player at [-9.0, 0.0, -8.0], Distance = 30.81
# Checking hit: Fireball at [-32.54188670549912, 0.0, -28.64320237487766], Player at [-9.0, 0.0, -8.0], Distance = 31.31
# Checking hit: Fireball at [-32.9251469460892, 0.0, -28.964312306182865], Player at [-9.0, 0.0, -8.0], Distance = 31.81
# Checking hit: Fireball at [-33.30840718667928, 0.0, -29.28542223748807], Player at [-9.0, 0.0, -8.0], Distance = 32.31
# Checking hit: Fireball at [-33.691667427269365, 0.0, -29.606532168793276], Player at [-9.0, 0.0, -8.0], Distance = 32.81
# Checking hit: Fireball at [-34.07492766785945, 0.0, -29.92764210009848], Player at [-9.0, 0.0, -8.0], Distance = 33.31
# Checking hit: Fireball at [-34.45818790844953, 0.0, -30.248752031403686], Player at [-9.0, 0.0, -8.0], Distance = 33.81
# Checking hit: Fireball at [-34.841448149039614, 0.0, -30.56986196270889], Player at [-9.0, 0.0, -8.0], Distance = 34.31
# Checking hit: Fireball at [-35.2247083896297, 0.0, -30.890971894014097], Player at [-9.0, 0.0, -8.0], Distance = 34.81
# Checking hit: Fireball at [-35.60796863021978, 0.0, -31.212081825319302], Player at [-9.0, 0.0, -8.0], Distance = 35.31
# Checking hit: Fireball at [-35.99122887080986, 0.0, -31.533191756624507], Player at [-9.0, 0.0, -8.0], Distance = 35.81
# Checking hit: Fireball at [-36.374489111399946, 0.0, -31.854301687929713], Player at [-9.0, 0.0, -8.0], Distance = 36.31
# Checking hit: Fireball at [-36.75774935199003, 0.0, -32.175411619234914], Player at [-9.0, 0.0, -8.0], Distance = 36.81
# Checking hit: Fireball at [-37.14100959258011, 0.0, -32.496521550540116], Player at [-9.0, 0.0, -8.0], Distance = 37.31
# Checking hit: Fireball at [-37.524269833170194, 0.0, -32.81763148184532], Player at [-9.0, 0.0, -8.0], Distance = 37.81
# Checking hit: Fireball at [-37.90753007376028, 0.0, -33.13874141315052], Player at [-9.0, 0.0, -8.0], Distance = 38.31
# Checking hit: Fireball at [-38.29079031435036, 0.0, -33.45985134445572], Player at [-9.0, 0.0, -8.0], Distance = 38.81
# Checking hit: Fireball at [-38.67405055494044, 0.0, -33.78096127576092], Player at [-9.0, 0.0, -8.0], Distance = 39.31
# Checking hit: Fireball at [-39.057310795530526, 0.0, -34.102071207066125], Player at [-9.0, 0.0, -8.0], Distance = 39.81
# Checking hit: Fireball at [-39.44057103612061, 0.0, -34.423181138371326], Player at [-9.0, 0.0, -8.0], Distance = 40.31
# Checking hit: Fireball at [-39.82383127671069, 0.0, -34.74429106967653], Player at [-9.0, 0.0, -8.0], Distance = 40.81
# Checking hit: Fireball at [-40.207091517300775, 0.0, -35.06540100098173], Player at [-9.0, 0.0, -8.0], Distance = 41.31
# Checking hit: Fireball at [-40.59035175789086, 0.0, -35.38651093228693], Player at [-9.0, 0.0, -8.0], Distance = 41.81
# Checking hit: Fireball at [-40.97361199848094, 0.0, -35.70762086359213], Player at [-9.0, 0.0, -8.0], Distance = 42.31
# Checking hit: Fireball at [-41.35687223907102, 0.0, -36.028730794897335], Player at [-9.0, 0.0, -8.0], Distance = 42.81
# Checking hit: Fireball at [-41.740132479661106, 0.0, -36.34984072620254], Player at [-9.0, 0.0, -8.0], Distance = 43.31
# Checking hit: Fireball at [-42.12339272025119, 0.0, -36.67095065750774], Player at [-9.0, 0.0, -8.0], Distance = 43.81
# Checking hit: Fireball at [-42.50665296084127, 0.0, -36.99206058881294], Player at [-9.0, 0.0, -8.0], Distance = 44.31
# Checking hit: Fireball at [-42.889913201431355, 0.0, -37.31317052011814], Player at [-9.0, 0.0, -8.0], Distance = 44.81
# Checking hit: Fireball at [-43.27317344202144, 0.0, -37.63428045142334], Player at [-9.0, 0.0, -8.0], Distance = 45.31
# Checking hit: Fireball at [-43.65643368261152, 0.0, -37.955390382728545], Player at [-9.0, 0.0, -8.0], Distance = 45.81
# Checking hit: Fireball at [-44.039693923201604, 0.0, -38.27650031403375], Player at [-9.0, 0.0, -8.0], Distance = 46.31
# Checking hit: Fireball at [-44.42295416379169, 0.0, -38.59761024533895], Player at [-9.0, 0.0, -8.0], Distance = 46.81
# Checking hit: Fireball at [-44.80621440438177, 0.0, -38.91872017664415], Player at [-9.0, 0.0, -8.0], Distance = 47.31
# Checking hit: Fireball at [-45.18947464497185, 0.0, -39.23983010794935], Player at [-9.0, 0.0, -8.0], Distance = 47.81
# Checking hit: Fireball at [-45.572734885561935, 0.0, -39.560940039254554], Player at [-9.0, 0.0, -8.0], Distance = 48.31
# Checking hit: Fireball at [-45.95599512615202, 0.0, -39.882049970559756], Player at [-9.0, 0.0, -8.0], Distance = 48.81
# Checking hit: Fireball at [-46.3392553667421, 0.0, -40.20315990186496], Player at [-9.0, 0.0, -8.0], Distance = 49.31
# Checking hit: Fireball at [-46.722515607332184, 0.0, -40.52426983317016], Player at [-9.0, 0.0, -8.0], Distance = 49.81
# Checking hit: Fireball at [-47.10577584792227, 0.0, -40.84537976447536], Player at [-9.0, 0.0, -8.0], Distance = 50.31
# Checking hit: Fireball at [-47.48903608851235, 0.0, -41.16648969578056], Player at [-9.0, 0.0, -8.0], Distance = 50.81
# Checking hit: Fireball at [-47.87229632910243, 0.0, -41.487599627085764], Player at [-9.0, 0.0, -8.0], Distance = 51.31
# Checking hit: Fireball at [-48.255556569692516, 0.0, -41.808709558390966], Player at [-9.0, 0.0, -8.0], Distance = 51.81
# Checking hit: Fireball at [-48.6388168102826, 0.0, -42.12981948969617], Player at [-9.0, 0.0, -8.0], Distance = 52.31
# Checking hit: Fireball at [-49.02207705087268, 0.0, -42.45092942100137], Player at [-9.0, 0.0, -8.0], Distance = 52.81
# Checking hit: Fireball at [-49.405337291462764, 0.0, -42.77203935230657], Player at [-9.0, 0.0, -8.0], Distance = 53.31
# Checking hit: Fireball at [-49.78859753205285, 0.0, -43.09314928361177], Player at [-9.0, 0.0, -8.0], Distance = 53.81
# 🔄 Game Reset!
# 🔄 Game Reset!
# 🔄 Game Reset!
# 🔄 Game Reset!
# Exception ignored on calling ctypes callback function: <function GLUTCallback.__call__.<locals>.safeCall at 0x0000024C2DE99800>
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\OpenGL\GLUT\special.py", line 130, in safeCall
#     return function( *args, **named )
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_9744\1100303211.py", line 207, in display
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
